# %% [markdown]
# <a href="https://colab.research.google.com/github/sharanyaa31/Adopted-User/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data1 = pd.read_excel("/Records Matching Task.xlsx")

# %%
data1.head()
# Out:
#          Order ID       Product ID  Qty
# 0  CA-2014-100006  TEC-PH-10002075  3.0
# 1  CA-2014-100090  FUR-TA-10003715  3.0
# 2  CA-2014-100090  OFF-BI-10001597  6.0
# 3  CA-2014-100293  OFF-PA-10000176  6.0
# 4  CA-2014-100328  OFF-BI-10000343  1.0

# %%
data1.info
# Out:
# <bound method DataFrame.info of             Order ID       Product ID  Qty
# 0     CA-2014-100006  TEC-PH-10002075  3.0
# 1     CA-2014-100090  FUR-TA-10003715  3.0
# 2     CA-2014-100090  OFF-BI-10001597  6.0
# 3     CA-2014-100293  OFF-PA-10000176  6.0
# 4     CA-2014-100328  OFF-BI-10000343  1.0
# ...              ...              ...  ...
# 9473  US-2017-169551  OFF-PA-10004100  3.0
# 9474  US-2017-169551  OFF-ST-10004835  3.0
# 9475  US-2017-169551  TEC-AC-10002018  3.0
# 9476  US-2017-169551  TEC-AC-10003033  2.0
# 9477  US-2017-169551  TEC-PH-10001363  2.0
#
# [9478 rows x 3 columns]>

# %%
data1['Data1_Unique_ID'] = data1['Order ID']+data1['Product ID']
data1
# Out:
#             Order ID       Product ID  Qty                Data1_Unique_ID
# 0     CA-2014-100006  TEC-PH-10002075  3.0  CA-2014-100006TEC-PH-10002075
# 1     CA-2014-100090  FUR-TA-10003715  3.0  CA-2014-100090FUR-TA-10003715
# 2     CA-2014-100090  OFF-BI-10001597  6.0  CA-2014-100090OFF-BI-10001597
# 3     CA-2014-100293  OFF-PA-10000176  6.0  CA-2014-100293OFF-PA-10000176
# 4     CA-2014-100328  OFF-BI-10000343  1.0  CA-2014-100328OFF-BI-10000343
# ...              ...              ...  ...                            ...
# 9473  US-2017-169551  OFF-PA-10004100  3.0  US-2017-169551OFF-PA-10004100
# 9474  US-2017-169551  OFF-ST-10004835  3.0  US-2017-169551OFF-ST-10004835
# 9475  US-2017-169551  TEC-AC-10002018  3.0  US-2017-169551TEC-AC-10002018
# 9476  US-2017-169551  TEC-AC-10003033  2.0  US-2017-169551TEC-AC-10003033
# 9477  US-2017-169551  TEC-PH-10001363  2.0  US-2017-169551TEC-PH-10001363
#
# [9478 rows x 4 columns]

# %%
data2 = pd.read_excel("/Records Matching Task (1).xlsx")

# %%
data2.head()
# Out:
#          Order ID       Product ID  Qty
# 0  CA-2014-100006  TEC-PH-10002075  3.0
# 1  CA-2014-100090  FUR-TA-10003715  3.0
# 2  CA-2014-100090  OFF-BI-10001597  6.0
# 3  CA-2014-100293  OFF-PA-10000176  6.0
# 4  CA-2014-100328  OFF-BI-10000343  1.0

# %%
data2.info
# Out:
# <bound method DataFrame.info of             Order ID       Product ID  Qty
# 0     CA-2014-100006  TEC-PH-10002075  3.0
# 1     CA-2014-100090  FUR-TA-10003715  3.0
# 2     CA-2014-100090  OFF-BI-10001597  6.0
# 3     CA-2014-100293  OFF-PA-10000176  6.0
# 4     CA-2014-100328  OFF-BI-10000343  1.0
# ...              ...              ...  ...
# 9473  US-2017-169551  OFF-PA-10004100  3.0
# 9474  US-2017-169551  OFF-ST-10004835  3.0
# 9475  US-2017-169551  TEC-AC-10002018  3.0
# 9476  US-2017-169551  TEC-AC-10003033  2.0
# 9477  US-2017-169551  TEC-PH-10001363  2.0
#
# [9478 rows x 3 columns]>

# %%
data2['Data2_Unique_ID'] = data2['Order ID']+data2['Product ID']
data2
# Out:
#             Order ID       Product ID  Qty                Data2_Unique_ID
# 0     CA-2014-100006  TEC-PH-10002075  3.0  CA-2014-100006TEC-PH-10002075
# 1     CA-2014-100090  FUR-TA-10003715  3.0  CA-2014-100090FUR-TA-10003715
# 2     CA-2014-100090  OFF-BI-10001597  6.0  CA-2014-100090OFF-BI-10001597
# 3     CA-2014-100293  OFF-PA-10000176  6.0  CA-2014-100293OFF-PA-10000176
# 4     CA-2014-100328  OFF-BI-10000343  1.0  CA-2014-100328OFF-BI-10000343
# ...              ...              ...  ...                            ...
# 9473  US-2017-169551  OFF-PA-10004100  3.0  US-2017-169551OFF-PA-10004100
# 9474  US-2017-169551  OFF-ST-10004835  3.0  US-2017-169551OFF-ST-10004835
# 9475  US-2017-169551  TEC-AC-10002018  3.0  US-2017-169551TEC-AC-10002018
# 9476  US-2017-169551  TEC-AC-10003033  2.0  US-2017-169551TEC-AC-10003033
# 9477  US-2017-169551  TEC-PH-10001363  2.0  US-2017-169551TEC-PH-10001363
#
# [9478 rows x 4 columns]

# %%
Final_data = data1.merge(data2, how='outer', left_on=['Data1_Unique_ID'], right_on=['Data2_Unique_ID'])

# %%
Final_data
# Out:
#           Order ID_x     Product ID_x  Qty_x                Data1_Unique_ID  \
# 0     CA-2014-100006  TEC-PH-10002075    3.0  CA-2014-100006TEC-PH-10002075
# 1     CA-2014-100090  FUR-TA-10003715    3.0  CA-2014-100090FUR-TA-10003715
# 2     CA-2014-100090  OFF-BI-10001597    6.0  CA-2014-100090OFF-BI-10001597
# 3     CA-2014-100293  OFF-PA-10000176    6.0  CA-2014-100293OFF-PA-10000176
# 4     CA-2014-100328  OFF-BI-10000343    1.0  CA-2014-100328OFF-BI-10000343
# ...              ...              ...    ...                            ...
# 9473  US-2017-169551  OFF-PA-10004100    3.0  US-2017-169551OFF-PA-10004100
# 9474  US-2017-169551  OFF-ST-10004835    3.0  US-2017-169551OFF-ST-10004835
# 9475  US-2017-169551  TEC-AC-10002018    3.0  US-2017-169551TEC-AC-10002018
# 9476  US-2017-169551  TEC-AC-10003033    2.0  US-2017-169551TEC-AC-10003033
# 9477  US-2017-169551  TEC-PH-10001363    2.0  US-2017-169551TEC-PH-10001363
#
# ...

# %% [markdown]
# How to identify the Records (Order ID + Product ID combination) present in data1 but missing in data2 (Specify the number of records missing in your answer)

# %%
Present_in_Data1_missing_in_data2 = Final_data[Final_data['Data2_Unique_ID'].isna()]

# %%
Present_in_Data1_missing_in_data2
# Out:
# Empty DataFrame
# Columns: [Order ID_x, Product ID_x, Qty_x, Data1_Unique_ID, Order ID_y, Product ID_y, Qty_y, Data2_Unique_ID]
# Index: []

# %%
Present_in_Data1_missing_in_data2.shape[0]
# Out:
# 0

# %% [markdown]
# How to identify the Records (Order ID + Product ID combination) missing in data1 but present in data2 (Specify the number of records missing in your answer)

# %%
Present_in_Data2_missing_in_data1 = Final_data[Final_data['Data1_Unique_ID'].isna()]
Present_in_Data2_missing_in_data1
# Out:
# Empty DataFrame
# Columns: [Order ID_x, Product ID_x, Qty_x, Data1_Unique_ID, Order ID_y, Product ID_y, Qty_y, Data2_Unique_ID]
# Index: []

# %%
Present_in_Data2_missing_in_data1.shape[0]
# Out:
# 0

# %%
Present_in_Data2_missing_in_data1['Qty_y'].sum()
# Out:
# 0.0
